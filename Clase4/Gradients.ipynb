# %% [markdown]
# # **H**istogram of **O**riented **G**radients (HOG)
#
# Images to use:
#   - [sudoku4.jpg](https://drive.google.com/file/d/1bxTtFUrykwYcyIbOZUs5AKQuTvvHGyxv/view?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
# Take an image - sudoku4.jpg (grayscale)
img = cv2.imread("/content/drive/MyDrive/PatronesClass2022/Repositorio/patrones/Clase4/sudoku4.jpg",0)

laplacian = cv2.Laplacian( img , cv2.CV_64F)
sobelx = cv2.Sobel( img , cv2.CV_64F, 1, 0, ksize=5)
sobely = cv2.Sobel( img , cv2.CV_64F, 0, 1, ksize=5)

# %%
plt.figure(figsize=(15,15))

plt.subplot(2,2,1), plt.title('Original')#, plt.xticks([]), plt.yticks([])
plt.imshow( img , cmap = 'gray')

plt.subplot(2,2,2), plt.title('Laplacian')#, plt.xticks([]), plt.yticks([])
plt.title('Sobel X'), plt.imshow( sobelx ,cmap = 'gray')

plt.subplot(2,2,3)#, plt.xticks([]), plt.yticks([])
plt.imshow( laplacian ,cmap = 'gray')

plt.subplot(2,2,4), plt.title('Sobel Y')#, plt.xticks([]), plt.yticks([])
plt.imshow( sobely ,cmap = 'gray')

plt.show()
